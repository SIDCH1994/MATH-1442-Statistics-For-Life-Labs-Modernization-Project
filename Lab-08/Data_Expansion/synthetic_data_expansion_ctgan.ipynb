# %% [markdown]
# # Synthetic Dataset Expansion using Conditional Tabular Generative Adversarial Network (CTGAN) method.
#
# The cleaned dataset Sleep_Study.csv is used for expansion

# %%
# %pip install sdv
# Out:
# Collecting sdv
#   Using cached sdv-1.32.0-py3-none-any.whl.metadata (14 kB)
# Collecting boto3<2.0.0,>=1.28 (from sdv)
#   Downloading boto3-1.42.18-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<2.0.0,>=1.31 (from sdv)
#   Downloading botocore-1.42.18-py3-none-any.whl.metadata (5.9 kB)
# Collecting cloudpickle>=2.1.0 (from sdv)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting graphviz>=0.13.2 (from sdv)
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from sdv) (2.3.5)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from sdv) (2.3.3)
# Collecting tqdm>=4.29 (from sdv)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting copulas>=0.12.1 (from sdv)
#   Using cached copulas-0.12.3-py3-none-any.whl.metadata (9.5 kB)
# Collecting ctgan>=0.11.1 (from sdv)
#   Using cached ctgan-0.11.1-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.7.0 (from sdv)
#   Using cached deepecho-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.18.2 (from sdv)
#   Using cached rdt-1.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.21.0 (from sdv)
#   Downloading sdmetrics-0.24.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: platformdirs>=4.0 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from sdv) (4.5.0)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from sdv) (6.0.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Collecting plotly>=5.10.0 (from copulas>=0.12.1->sdv)
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: scipy>=1.9.2 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from copulas>=0.12.1->sdv) (1.16.3)
# Collecting torch>=2.0.0 (from ctgan>=0.11.1->sdv)
#   Downloading torch-2.9.1-cp311-cp311-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: colorama in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from tqdm>=4.29->sdv) (0.4.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (2.7.0)
# Requirement already satisfied: packaging in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: scikit-learn>=1.1.3 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from rdt>=1.18.2->sdv) (1.7.2)
# Collecting Faker!=37.11.0,>=17 (from rdt>=1.18.2->sdv)
#   Downloading faker-40.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from scikit-learn>=1.1.3->rdt>=1.18.2->sdv) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from scikit-learn>=1.1.3->rdt>=1.18.2->sdv) (3.5.0)
# Collecting filelock (from torch>=2.0.0->ctgan>=0.11.1->sdv)
#   Downloading filelock-3.20.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (4.15.0)
# Collecting sympy>=1.13.3 (from torch>=2.0.0->ctgan>=0.11.1->sdv)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=2.0.0->ctgan>=0.11.1->sdv)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from torch>=2.0.0->ctgan>=0.11.1->sdv) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch>=2.0.0->ctgan>=0.11.1->sdv)
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.0.0->ctgan>=0.11.1->sdv)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\siddh\anaconda3\envs\sidd_ds\lib\site-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.1->sdv) (3.0.2)
# Using cached sdv-1.32.0-py3-none-any.whl (198 kB)
# Downloading boto3-1.42.18-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.18-py3-none-any.whl (14.5 MB)
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------  14.4/14.5 MB 82.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.5/14.5 MB 65.2 MB/s  0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached copulas-0.12.3-py3-none-any.whl (52 kB)
# Using cached ctgan-0.11.1-py3-none-any.whl (25 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached deepecho-0.7.0-py3-none-any.whl (27 kB)
# Using cached graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 9.9/9.9 MB 77.0 MB/s  0:00:00
# Using cached rdt-1.18.2-py3-none-any.whl (74 kB)
# Downloading faker-40.1.0-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 55.6 MB/s  0:00:00
# Downloading sdmetrics-0.24.0-py3-none-any.whl (198 kB)
# Downloading torch-2.9.1-cp311-cp311-win_amd64.whl (111.0 MB)
#    ---------------------------------------- 0.0/111.0 MB ? eta -:--:--
#    --------- ----------------------------- 26.5/111.0 MB 139.4 MB/s eta 0:00:01
#    ------------------ -------------------- 53.5/111.0 MB 130.7 MB/s eta 0:00:01
#    ------------------------ -------------- 69.7/111.0 MB 111.1 MB/s eta 0:00:01
#    ---------------------------- ---------- 81.0/111.0 MB 101.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 96.5/111.0 MB 91.9 MB/s eta 0:00:01
#    --------------------------------------  110.9/111.0 MB 95.6 MB/s eta 0:00:01
#    ---------------------------------------- 111.0/111.0 MB 79.6 MB/s  0:00:01
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 112.9 MB/s  0:00:00
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading filelock-3.20.1-py3-none-any.whl (16 kB)
# Installing collected packages: mpmath, tqdm, sympy, plotly, networkx, jmespath, graphviz, fsspec, filelock, Faker, cloudpickle, torch, botocore, s3transfer, rdt, deepecho, copulas, sdmetrics, ctgan, boto3, sdv
#
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    - --------------------------------------  1/21 [tqdm]
#    - --------------------------------------  1/21 [tqdm]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    --- ------------------------------------  2/21 [sympy]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ----- ----------------------------------  3/21 [plotly]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    ------- --------------------------------  4/21 [networkx]
#    --------- ------------------------------  5/21 [jmespath]
#    ----------- ----------------------------  6/21 [graphviz]
#    ----------- ----------------------------  6/21 [graphviz]
#    ------------- --------------------------  7/21 [fsspec]
#    ------------- --------------------------  7/21 [fsspec]
#    ------------- --------------------------  7/21 [fsspec]
#    ------------- --------------------------  7/21 [fsspec]
#    ------------- --------------------------  7/21 [fsspec]
#    --------------- ------------------------  8/21 [filelock]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ----------------- ----------------------  9/21 [Faker]
#    ------------------- -------------------- 10/21 [cloudpickle]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    -------------------- ------------------- 11/21 [torch]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ---------------------- ----------------- 12/21 [botocore]
#    ------------------------ --------------- 13/21 [s3transfer]
#    -------------------------- ------------- 14/21 [rdt]
#    -------------------------- ------------- 14/21 [rdt]
#    ---------------------------- ----------- 15/21 [deepecho]
#    ------------------------------ --------- 16/21 [copulas]
#    ------------------------------ --------- 16/21 [copulas]
#    -------------------------------- ------- 17/21 [sdmetrics]
#    -------------------------------- ------- 17/21 [sdmetrics]
#    -------------------------------- ------- 17/21 [sdmetrics]
#    -------------------------------- ------- 17/21 [sdmetrics]
#    -------------------------------- ------- 17/21 [sdmetrics]
#    -------------------------------- ------- 17/21 [sdmetrics]
#    -------------------------------- ------- 17/21 [sdmetrics]
#    ---------------------------------- ----- 18/21 [ctgan]
#    ------------------------------------ --- 19/21 [boto3]
#    ------------------------------------ --- 19/21 [boto3]
#    ------------------------------------ --- 19/21 [boto3]
#    -------------------------------------- - 20/21 [sdv]
#    -------------------------------------- - 20/21 [sdv]
#    -------------------------------------- - 20/21 [sdv]
#    -------------------------------------- - 20/21 [sdv]
#    -------------------------------------- - 20/21 [sdv]
#    -------------------------------------- - 20/21 [sdv]
#    ---------------------------------------- 21/21 [sdv]
#
# Successfully installed Faker-40.1.0 boto3-1.42.18 botocore-1.42.18 cloudpickle-3.1.2 copulas-0.12.3 ctgan-0.11.1 deepecho-0.7.0 filelock-3.20.1 fsspec-2025.12.0 graphviz-0.21 jmespath-1.0.1 mpmath-1.3.0 networkx-3.6.1 plotly-6.5.0 rdt-1.18.2 s3transfer-0.16.0 sdmetrics-0.24.0 sdv-1.32.0 sympy-1.14.0 torch-2.9.1 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\siddh\anaconda3\envs\sidd_ds\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'C:\Users\siddh\anaconda3\envs\sidd_ds\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script plotly_get_chrome.exe is installed in 'C:\Users\siddh\anaconda3\envs\sidd_ds\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script faker.exe is installed in 'C:\Users\siddh\anaconda3\envs\sidd_ds\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\siddh\anaconda3\envs\sidd_ds\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# ============================================================
# Sleep_Study → expand to 1000 rows with CTGAN (SDV)
# - Handles mixed types (categorical + numeric)
# - Enforces rounding for integer-like fields
# - Enforces min/max bounds for numerics
# - Validates proportions & numeric drift
# ============================================================
from sdv.single_table import CTGANSynthesizer, GaussianCopulaSynthesizer
from sdv.metadata import SingleTableMetadata

# %%
import numpy as np
import pandas as pd
from scipy.stats import ks_2samp

# %%
# -------------------------------
# 1) Load data
# -------------------------------
df = pd.read_csv(r'..\Data_Cleaning\Sleep_Study.csv')
print("Loaded:", df.shape)
# Out:
# Loaded: (253, 23)

# %%
# -------------------------------
# 2) Column lists (from your dataset introspection)
# -------------------------------
categorical_cols = ['GENDER', 'CL_YEAR', 'LNO', 'DEP_STATUS', 'ANX_STATUS', 'STRESS', 'ALCO_USE']
numeric_cols = ['GPA', 'COG_ZSCORE', 'PS_QUAL', 'DEP_SCORE', 'ANX_SCORE', 'STR_SCORE',
                'DAS_SCORE', 'HAPPINESS', 'DRINKS', 'WD_BED', 'WD_RISE', 'WD_SLEEP',
                'WE_BED', 'WeekendRise', 'WE_SLEEP', 'AVG_SLEEP']

# Integer-like numeric columns (scores, counts) to round after sampling
integer_cols = ['PS_QUAL','DEP_SCORE','ANX_SCORE','STR_SCORE','DAS_SCORE','HAPPINESS','DRINKS']

# %%
# -------------------------------
# 3) Prepare training data
# -------------------------------
train_df = df.copy()

# IMPORTANT: categoricals must be plain object for CTGAN (not pandas 'category')
for c in categorical_cols:
    if c in train_df.columns:
        train_df[c] = train_df[c].astype(object)

# Drop constant/empty columns (rare, but safe)
const_or_allna = [c for c in train_df.columns if train_df[c].nunique(dropna=True) <= 1]
if const_or_allna:
    train_df = train_df.drop(columns=const_or_allna)
    categorical_cols = [c for c in categorical_cols if c not in const_or_allna]
    numeric_cols     = [c for c in numeric_cols if c not in const_or_allna]
    integer_cols     = [c for c in integer_cols if c not in const_or_allna]

# %%
# -------------------------------
# 4) SDV metadata
# -------------------------------
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(train_df)

# Force intended sdtypes
for c in categorical_cols:
    if c in metadata.columns:
        metadata.update_column(c, sdtype="categorical")

for c in numeric_cols:
    if c in metadata.columns:
        metadata.update_column(c, sdtype="numerical")

print("Metadata ready.")
# Out:
# Metadata ready.

# %%
# -------------------------------
# 5) Train CTGAN (tuned for stability on this size)
# -------------------------------
synth = CTGANSynthesizer(
    metadata,
    epochs=800,                 # a bit longer for tighter marginals
    batch_size=100,             # multiple of pac
    pac=10,                     # default = 10; matches batch_size
    verbose=True,
    enforce_min_max_values=True,
    enforce_rounding=True,      # helps keep integer-like numerics as ints
    cuda=False                  # force CPU (safer if CUDA not configured)
)

# Fit
synth.fit(train_df)
# Out:
# C:\Users\siddh\anaconda3\envs\sidd_ds\Lib\site-packages\sdv\single_table\base.py:168: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# C:\Users\siddh\anaconda3\envs\sidd_ds\Lib\site-packages\sdv\single_table\base.py:134: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# C:\Users\siddh\anaconda3\envs\sidd_ds\Lib\site-packages\ctgan\synthesizers\_utils.py:16: FutureWarning: `cuda` parameter is deprecated and will be removed in a future release. Please use `enable_gpu` instead.
#   warnings.warn(
# Gen. (-4.30) | Discrim. (0.25): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 800/800 [02:18<00:00,  5.79it/s]

# %%
# -------------------------------
# 6) Sample to reach 1000 rows
# -------------------------------
TARGET_ROWS = 1000
need_rows = max(0, TARGET_ROWS - len(df))
print("Need to generate:", need_rows)

if need_rows > 0:
    synth_new = synth.sample(num_rows=need_rows)

    # Post-process: ensure types + light rounding/clipping safety
    for c in categorical_cols:
        if c in synth_new.columns:
            synth_new[c] = synth_new[c].astype(object)

    for c in numeric_cols:
        if c in synth_new.columns and c in df.columns:
            synth_new[c] = pd.to_numeric(synth_new[c], errors="coerce")
            # Optional extra safety: clip to observed range
            synth_new[c] = synth_new[c].clip(df[c].min(), df[c].max())

    # Ensure integer-like columns are whole numbers
    for c in integer_cols:
        if c in synth_new.columns:
            synth_new[c] = pd.to_numeric(synth_new[c], errors="coerce").round().astype('Int64')

    # Reassemble in original column order
    out = pd.concat(
        [df.reset_index(drop=True),
         synth_new.reindex(columns=df.columns)],
        ignore_index=True
    )
else:
    out = df.copy()

print("Final shape:", out.shape)
# Out:
# Need to generate: 747
# Final shape: (1000, 23)

# %%
# -------------------------------
# 7) Validation summaries
# -------------------------------
def cat_props(frame, cols, k=20):
    rep = {}
    for c in cols:
        if c in frame.columns:
            rep[c] = frame[c].value_counts(normalize=True, dropna=False).head(k).round(3)
    return rep

print("\n=== Categorical Proportions (original vs expanded) ===")
orig_cat = cat_props(df, categorical_cols)
new_cat  = cat_props(out, categorical_cols)

for c in categorical_cols:
    if c in orig_cat:
        print(f"\n[{c}]")
        print("Original:\n", orig_cat[c])
        print("Expanded:\n", new_cat[c])

def numeric_summary(frame, cols):
    if not cols: 
        return pd.DataFrame()
    return frame[cols].describe().T[['mean','std','min','25%','50%','75%','max']].round(3)

print("\n=== Numeric Summary (original vs expanded) ===")
print("Original:\n", numeric_summary(df, numeric_cols))
print("\nExpanded:\n", numeric_summary(out, numeric_cols))

# KS tests to quantify distribution similarity (lower KS_stat & higher p are better)
ks_rows = []
for c in [col for col in numeric_cols if col in out.columns]:
    dstat, pval = ks_2samp(df[c].dropna(), out[c].dropna())
    ks_rows.append((c, float(dstat), float(pval)))
ks_df = pd.DataFrame(ks_rows, columns=["column","KS_stat","p_value"]).sort_values("KS_stat")
print("\n=== Kolmogorov–Smirnov tests (numeric) ===")
print(ks_df)

# Correlation drift
common_num = [c for c in numeric_cols if c in df.columns and c in out.columns]
if common_num:
    corr_orig = df[common_num].corr(numeric_only=True)
    corr_new  = out[common_num].corr(numeric_only=True)
    corr_diff = (corr_new - corr_orig).abs().mean().mean()
    print("\nMean abs correlation drift:", round(float(corr_diff), 3))
# Out:
# === Categorical Proportions (original vs expanded) ===
#
# [GENDER]
# Original:
#  GENDER
# Male      0.597
# Female    0.403
# Name: proportion, dtype: float64
# Expanded:
#  GENDER
# Male      0.666
# Female    0.334
# Name: proportion, dtype: float64
#
# [CL_YEAR]
# Original:
#  CL_YEAR
# Sophomore    0.375
# Senior       0.225
# Junior       0.213
# Freshman     0.186
# Name: proportion, dtype: float64
# Expanded:
#  CL_YEAR
# Sophomore    0.386
# Junior       0.262
# Senior       0.193
# Freshman     0.159
# Name: proportion, dtype: float64
#
# [LNO]
# Original:
#  LNO
# Neither    0.644
# Owl        0.194
# Lark       0.162
# Name: proportion, dtype: float64
# Expanded:
#  LNO
# Neither    0.659
# Owl        0.187
# Lark       0.154
# Name: proportion, dtype: float64
#
# [DEP_STATUS]
# Original:
#  DEP_STATUS
# normal      0.826
# moderate    0.134
# severe      0.040
# Name: proportion, dtype: float64
# Expanded:
#  DEP_STATUS
# normal      0.794
# moderate    0.151
# severe      0.055
# Name: proportion, dtype: float64
#
# [ANX_STATUS]
# Original:
#  ANX_STATUS
# normal      0.715
# moderate    0.221
# severe      0.063
# Name: proportion, dtype: float64
# Expanded:
#  ANX_STATUS
# normal      0.654
# moderate    0.264
# severe      0.082
# Name: proportion, dtype: float64
#
# [STRESS]
# Original:
#  STRESS
# normal    0.779
# high      0.221
# Name: proportion, dtype: float64
# Expanded:
#  STRESS
# normal    0.639
# high      0.361
# Name: proportion, dtype: float64
#
# [ALCO_USE]
# Original:
#  ALCO_USE
# Moderate    0.474
# Light       0.328
# Abstain     0.134
# Heavy       0.063
# Name: proportion, dtype: float64
# Expanded:
#  ALCO_USE
# Moderate    0.452
# Light       0.307
# Abstain     0.148
# Heavy       0.093
# Name: proportion, dtype: float64
#
# === Numeric Summary (original vs expanded) ===
# Original:
#                 mean     std    min    25%    50%    75%    max
# GPA           3.244   0.404   2.00   3.00   3.30   3.50   4.00
# COG_ZSCORE   -0.000   0.707  -1.62  -0.48  -0.01   0.44   1.96
# PS_QUAL       6.257   2.920   1.00   4.00   6.00   8.00  18.00
# DEP_SCORE     5.202   6.001   0.00   1.00   3.00   7.00  35.00
# ANX_SCORE     5.372   5.197   0.00   1.00   4.00   8.00  26.00
# STR_SCORE     9.466   7.952   0.00   3.00   8.00  14.00  37.00
# DAS_SCORE    20.040  16.542   0.00   7.00  16.00  28.00  82.00
# HAPPINESS    26.111   5.488   0.00  24.00  28.00  30.00  35.00
# DRINKS        5.569   4.095   0.00   3.00   5.00   8.00  24.00
# WD_BED       24.848   1.034  21.80  24.20  24.80  25.50  29.10
# WD_RISE       8.586   0.943   5.50   8.00   8.50   9.15  12.02
# WD_SLEEP      7.866   1.168   3.00   7.20   7.95   8.60  10.97
# WE_BED       25.585   1.273  21.50  24.88  25.50  26.25  30.25
# WeekendRise  10.204   1.401   5.25   9.25  10.25  11.00  15.00
# WE_SLEEP      8.217   1.367   4.00   7.25   8.25   9.25  12.75
# AVG_SLEEP     7.966   0.965   4.95   7.43   8.00   8.59  10.62
#
# Expanded:
#                   mean        std   min     25%     50%      75%    max
# GPA           3.48144   0.496668   2.0    3.15    3.58      4.0    4.0
# COG_ZSCORE    0.05512   0.928357 -1.62   -0.62    0.04     0.73   1.96
# PS_QUAL         7.896   3.739675   1.0     5.0     8.0     10.0   18.0
# DEP_SCORE       9.872   9.550855   0.0     3.0     7.0     14.0   35.0
# ANX_SCORE       8.024   6.852619   0.0     3.0     6.0     12.0   26.0
# STR_SCORE       12.55  10.245998   0.0     5.0    10.0     18.0   37.0
# DAS_SCORE      31.317  24.268157   0.0    12.0    25.0     46.0   82.0
# HAPPINESS      28.848   6.531735   0.0    26.0    30.0     35.0   35.0
# DRINKS          8.395   5.289324   0.0     4.0     8.0     12.0   24.0
# WD_BED       25.21466   1.473802  21.8   24.13  25.175    26.29   29.1
# WD_RISE        7.5481   1.376216   5.5    6.46     7.5     8.47  12.02
# WD_SLEEP      8.64607   1.521562   3.0    7.66   8.755     9.79  10.97
# WE_BED       26.67345   1.748722  21.5    25.5   26.75  27.8625  30.25
# WeekendRise     9.029   1.895941  5.25  7.5575    8.93    10.42   15.0
# WE_SLEEP      7.42985   1.825469   4.0  6.0575     7.5     8.76  12.75
# AVG_SLEEP     8.27173   1.240908  4.95    7.47    8.32   9.1725  10.62
#
# === Kolmogorov–Smirnov tests (numeric) ===
#          column   KS_stat       p_value
# 1    COG_ZSCORE  0.094229  5.131957e-02
# 5     STR_SCORE  0.125170  3.202340e-03
# 15    AVG_SLEEP  0.177565  4.816928e-06
# 9        WD_BED  0.195850  2.911883e-07
# 4     ANX_SCORE  0.197123  2.380898e-07
# 2       PS_QUAL  0.220648  4.147937e-09
# 6     DAS_SCORE  0.222419  2.985290e-09
# 14     WE_SLEEP  0.234423  3.095981e-10
# 8        DRINKS  0.251949  9.059015e-12
# 3     DEP_SCORE  0.275506  5.194456e-14
# 11     WD_SLEEP  0.310423  9.847465e-18
# 0           GPA  0.311992  6.528870e-18
# 7     HAPPINESS  0.326186  1.440068e-19
# 13  WeekendRise  0.346897  3.948561e-22
# 12       WE_BED  0.362134  3.992883e-24
# 10      WD_RISE  0.416755  4.522817e-32
#
# Mean abs correlation drift: 0.176

# %%
# -------------------------------
# 8) Save
# -------------------------------
OUT_CSV = "SStudy.csv"
out.to_csv(OUT_CSV, index=False)
print(f"\nSaved → {OUT_CSV}")
# Out:
# Saved → SStudy.csv

# %%
# -------------------------------
# 9) OPTIONAL: Gaussian Copula baseline (toggle if desired)
# -------------------------------
USE_COPULA = False  # set to True to also generate a copula-based expansion
if USE_COPULA:
    gc = GaussianCopulaSynthesizer(
        metadata,
        enforce_min_max_values=True,
        enforce_rounding=True
    )
    gc.fit(df)
    need_rows_gc = max(0, TARGET_ROWS - len(df))
    gc_new = gc.sample(need_rows_gc)
    out_gc = pd.concat([df, gc_new.reindex(columns=df.columns)], ignore_index=True)
    out_gc.to_csv("SStudy.csv", index=False)
    print("Also saved → SStudy.csv")
